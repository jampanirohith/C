# %%
import csv
with open('/home/user/Desktop/17-03-2026/data.csv','r') as file:
    read = csv.reader(file)
    for row in read:
        print(row)
# Out:
# ['Name', 'Class']
# ['Ram', 'xi']
# ['Ajith', 'xii']

# %%
with open('/home/user/Desktop/17-03-2026/data.csv','r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        print(dict(row))
# Out:
# {'Name': 'Ram', 'Class': 'xi'}
# {'Name': 'Ajith', 'Class': 'xii'}

# %%
import csv

with open('/home/user/Desktop/17-03-2026/data1.csv', 'w') as file:
    write = csv.writer(file)
    write.writerow(['Name', 'Class'])
    write.writerow(['Ram', 'xi'])
    write.writerow(['Ajith', 'xii'])

with open('/home/user/Desktop/17-03-2026/data1.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        print(row)
# Out:
# {'Name': 'Ram', 'Class': 'xi'}
# {'Name': 'Ajith', 'Class': 'xii'}

# %%
import csv

with open('/home/user/Desktop/17-03-2026/data2.csv', 'w') as file:
    write = csv.writer(file)
    feild = ['Name', 'Class']
    rows = [['Ram', 'xi'], ['Ajith','xii']]
    write.writerow(feild)
    write.writerow(rows)

with open('/home/user/Desktop/17-03-2026/data2.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        print(dict(row))
# Out:
# {'Name': "['Ram', 'xi']", 'Class': "['Ajith', 'xii']"}

# %%
filename = "/home/user/Desktop/17-03-2026/imbd_top_4.csv"
header = ("Rank", "Rating", "Title")
data = [
    (1, 9.2, "The Shawshank Redemption(1994)"),
    (2, 9.2, "The Godfather(1972)"),
    (3, 9, "The Godfather: Part II(1974)"),
    (4, 8.9, "Pulp Fiction(1994)")
]

# %%
def writer(header, data, filename):
    with open(filename, "w", newline = "") as csvfile:
        movies = csv.writer(csvfile)
        movies.writerow(header)
        movies.writerows(data)

writer(header, data, filename)

# %%
with open('/home/user/Desktop/17-03-2026/imbd_top_4.csv','r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        print(dict(row))
# Out:
# {'Rank': '1', 'Rating': '9.2', 'Title': 'The Shawshank Redemption(1994)'}
# {'Rank': '2', 'Rating': '9.2', 'Title': 'The Godfather(1972)'}
# {'Rank': '3', 'Rating': '9', 'Title': 'The Godfather: Part II(1974)'}
# {'Rank': '4', 'Rating': '8.9', 'Title': 'Pulp Fiction(1994)'}

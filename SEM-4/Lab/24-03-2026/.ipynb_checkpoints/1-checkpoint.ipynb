# %%
import pandas as pd

data = {
    'Student Name': ['Ahmad', 'Ali', 'Sara'],
    'ID': [1, 15, 7],
    'GPA': [3.5, 3.5, 3.2],
    'SSN': [1234567890, 1111222222, 4444422211]
}

df = pd.DataFrame(data)

df.to_csv('pandas-result.csv', index=False)

print("File saved successfully")
# Out:
# File saved successfully

# %%
import pandas 
result = pandas.read_csv('pandas-result.csv')
print(type(result))
print(result)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#   Student Name  ID  GPA         SSN
# 0        Ahmad   1  3.5  1234567890
# 1          Ali  15  3.5  1111222222
# 2         Sara   7  3.2  4444422211
